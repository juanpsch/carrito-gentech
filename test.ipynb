# %%
import camelot
import pandas as pd
import json
import os
import re
import sys
# Out:
# d:\Users\juanp_schamun\AppData\Local\anaconda3\envs\pdf_env\lib\site-packages\pypdf\_crypt_providers\_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %%
import camelot
import pandas as pd
import json
import os
import re
import sys

def extract_tables_from_pdf(pdf_path, output_json_path):
    """
    Extrae tablas de un archivo PDF y las guarda en un archivo JSON.
    Este script está optimizado para la estructura del PDF de GENTECH y
    ahora incluye una lógica para detectar y categorizar los productos,
    manejando celdas combinadas de forma más robusta.

    Args:
        pdf_path (str): La ruta del archivo PDF de entrada.
        output_json_path (str): La ruta donde se guardará el archivo JSON de salida.
    """
    # Verificar si el archivo PDF existe
    if not os.path.exists(pdf_path):
        print(f"Error: El archivo PDF '{pdf_path}' no se encontró.")
        return

    try:
        # 1. Extracción con coordenadas específicas
        print(f"🕵️‍♂️ Extrayendo tablas de '{pdf_path}' usando coordenadas y el método 'stream'...")
        tables = camelot.read_pdf(pdf_path, flavor='stream', pages='1', table_areas=['50,780,800,0'])

        if tables.n == 0:
            print("❌ No se encontraron tablas. Verifique las coordenadas o el tipo de tabla.")
            return

        all_tables_data = []

        # 2. Transformación y Limpieza de la tabla extraída
        for i, table in enumerate(tables):
            df = table.df.copy()
            
            # Limpiar los datos de la tabla, eliminando espacios extra
            df = df.map(lambda x: str(x).strip() if isinstance(x, str) else x)

            # Eliminar filas completamente vacías
            df.dropna(how='all', inplace=True)
            
            # Eliminar la fila de encabezado que a veces se extrae
            df = df[~df.iloc[:, 0].str.contains('DESCRIPCIÓN', na=False)]
            
            # Reorganizar los encabezados y datos
            df.columns = ['DESCRIPCIÓN', 'PRESENTACIÓN', 'CONTENIDO NETO', 'CANTIDAD POR BULTO', 'PRECIO UNITARIO NETO', 'PRECIO UNITARIO CON IVA']

            products = []
            current_category = 'Sin Categoria'
            last_product_desc = ""

            for idx, row in df.iterrows():
                row_values_str = ' '.join(str(val) for val in row.tolist()).upper()
                
                # Detectar las filas de categorías
                category_keywords = ['LINEA ALTO RENDIMIENTO', 'LINEA PREMIUM', 'LINEA IRON', 'LINEA BEAUTY', 'LINEA PRE_WORKOUT', 'LINEA NUTRICION',
                                      'LINEA KIDS', 'LINEA VEGGIE PLANT BASED', 'ACCESORIOS']
                is_category_row = any(keyword in row_values_str for keyword in category_keywords)

                if is_category_row:
                    category_name = next((val for val in row.tolist() if str(val).strip()), None)
                    if category_name:
                        cleaned_name = re.sub(r'(LÍNEA|LINEA)\s*', '', str(category_name), flags=re.IGNORECASE).strip()
                        if cleaned_name.upper() not in ['DESCRIPCIÓN', 'PRESENTACIÓN', 'CONTENIDO NETO', 'CANTIDAD POR BULTO', 'PRECIO UNITARIO NETO', 'PRECIO UNITARIO CON IVA']:
                            current_category = cleaned_name
                    continue

                # Si la fila tiene una descripción no vacía, es un producto principal
                if str(row['DESCRIPCIÓN']).strip():
                    last_product_desc = str(row['DESCRIPCIÓN'])

                # Comprobar si la fila contiene múltiples entradas de producto debido a celdas combinadas
                # y dividir todas las columnas relevantes por el salto de línea
                if '\n' in str(row['PRESENTACIÓN']) or '\n' in str(row['CONTENIDO NETO']) or '\n' in str(row['PRECIO UNITARIO CON IVA']):
                    presentaciones = str(row['PRESENTACIÓN']).split('\n')
                    contenidos = str(row['CONTENIDO NETO']).split('\n')
                    cantidades = str(row['CANTIDAD POR BULTO']).split('\n')
                    precios_netos = str(row['PRECIO UNITARIO NETO']).split('\n')
                    precios_iva = str(row['PRECIO UNITARIO CON IVA']).split('\n')

                    # Iterar sobre las partes divididas para crear un producto por cada una
                    # Ahora se usa el largo de la lista de precios_iva, que es el más fiable
                    for j in range(len(precios_iva)):
                        product_row = {
                            'Categoria': current_category,
                            'DESCRIPCIÓN': last_product_desc,  # Asignamos la última descripción válida
                            'PRESENTACIÓN': presentaciones[j].strip() if j < len(presentaciones) else '',
                            'CONTENIDO NETO': contenidos[j].strip() if j < len(contenidos) else '',
                            'CANTIDAD POR BULTO': cantidades[j].strip() if j < len(cantidades) else '',
                            'PRECIO UNITARIO NETO': precios_netos[j].strip() if j < len(precios_netos) else '',
                            'PRECIO UNITARIO CON IVA': precios_iva[j].strip()
                        }
                        products.append(product_row)
                
                # Si es una fila de producto normal (sin celdas combinadas), lo procesamos
                elif str(row['PRECIO UNITARIO CON IVA']).strip():
                    product_row = {
                        'Categoria': current_category,
                        'DESCRIPCIÓN': last_product_desc,
                        'PRESENTACIÓN': row['PRESENTACIÓN'],
                        'CONTENIDO NETO': row['CONTENIDO NETO'],
                        'CANTIDAD POR BULTO': row['CANTIDAD POR BULTO'],
                        'PRECIO UNITARIO NETO': row['PRECIO UNITARIO NETO'],
                        'PRECIO UNITARIO CON IVA': row['PRECIO UNITARIO CON IVA']
                    }
                    products.append(product_row)
            
            all_tables_data.append({"tabla_1": products})

            return products

        # # 3. Carga: Escribir los datos en el archivo JSON
        # with open(output_json_path, 'w', encoding='utf-8') as f:
        #     json.dump(all_tables_data, f, ensure_ascii=False, indent=4)
        
        # print(f"✅ ¡Éxito! {tables.n} tablas extraídas y guardadas en '{output_json_path}'.")

    except Exception as e:
        print(f"❌ Ocurrió un error inesperado: {e}")
        # En caso de error, imprimir el DataFrame para depuración
        try:
            print("--- Contenido del DataFrame para depuración ---")
            print(df)
            print("---------------------------------------------")
        except NameError:
            pass

# %%
pdf_file_path = 'LISTA DE PRECIOS MAYORISTA - GENTECH - SEPTIEMBRE 2025.pdf'
output_json_file = 'test.json'

tablas = extract_tables_from_pdf(pdf_file_path, output_json_file)
tablas
# Out:
# 🕵️‍♂️ Extrayendo tablas de 'LISTA DE PRECIOS MAYORISTA - GENTECH - SEPTIEMBRE 2025.pdf' usando coordenadas y el método 'stream'...
# [{'Categoria': 'Sin Categoria',
#   'DESCRIPCIÓN': '',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '',
#   'PRECIO UNITARIO CON IVA': 'IVA'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': '',
#   'PRESENTACIÓN': 'POTE -150 COMPRIMIDOS',
#   'CONTENIDO NETO': '285',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': '',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '11.424,79',
#   'PRECIO UNITARIO CON IVA': '13.824,00'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': '',
#   'PRESENTACIÓN': 'POTE - 325 COMPRIMIDOS',
#   'CONTENIDO NETO': '618',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': '',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '22.849,59',
#   'PRECIO UNITARIO CON IVA': '27.648,00'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'AMINO 9000 - DULCE DE LECHE / FRUTILLA',
#   'PRESENTACIÓN': 'DOYPACK -160 COMPRIMIDOS',
#   'CONTENIDO NETO': '480',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'AMINO 9000 - DULCE DE LECHE / FRUTILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '13.566,94',
#   'PRECIO UNITARIO CON IVA': '16.416,00'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'AMINO 9000 - DULCE DE LECHE / FRUTILLA',
#   'PRESENTACIÓN': 'FRASCO - 120 COMPRIMIDOS',
#   'CONTENIDO NETO': '168',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'AMINO 9000 - DULCE DE LECHE / FRUTILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '8.759,01',
#   'PRECIO UNITARIO CON IVA': '10.598,40'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'C.D.S. (CREATINE DELIVERY SYSTEM) - FRUTAS TROPICALES - KOSHER',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '800',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'C.D.S. (CREATINE DELIVERY SYSTEM) - FRUTAS TROPICALES - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '12.472,07',
#   'PRECIO UNITARIO CON IVA': '15.091,20'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'C.D.S. (CREATINE DELIVERY SYSTEM) - FRUTAS TROPICALES - KOSHER',
#   'PRESENTACIÓN': 'FRASCO - 90 CAPSULAS',
#   'CONTENIDO NETO': '41',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'C.D.S. (CREATINE DELIVERY SYSTEM) - FRUTAS TROPICALES - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '7.521,32',
#   'PRECIO UNITARIO CON IVA': '9.100,80'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'CARTÍLAGO DE TIBURÓN',
#   'PRESENTACIÓN': 'FRASCO - 60 COMPRIMIDOS',
#   'CONTENIDO NETO': '72',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'CARTÍLAGO DE TIBURÓN',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '6.188,43',
#   'PRECIO UNITARIO CON IVA': '7.488,00'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'CREATINA MASTICABLE - FRUTILLA',
#   'PRESENTACIÓN': 'POTE -150 COMPRIMIDOS',
#   'CONTENIDO NETO': '437',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'CREATINA MASTICABLE - FRUTILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '13.519,34',
#   'PRECIO UNITARIO CON IVA': '16.358,40'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'CREATINA MONOHIDRATO - AFA - KOSHER',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '250',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'CREATINA MONOHIDRATO - AFA - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '16.232,73',
#   'PRECIO UNITARIO CON IVA': '19.641,60'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'CREATINA MONOHIDRATO - AFA - KOSHER',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '500',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'CREATINA MONOHIDRATO - AFA - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '29.038,02',
#   'PRECIO UNITARIO CON IVA': '35.136,00'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'CREATINA MONOHIDRATO - AFA - KOSHER',
#   'PRESENTACIÓN': 'FRASCO - 120 CAPSULAS',
#   'CONTENIDO NETO': '54',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'CREATINA MONOHIDRATO - AFA - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '8.235,37',
#   'PRECIO UNITARIO CON IVA': '9.964,80'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'MAXI GAIN - AFA - BANANA, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '750',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'MAXI GAIN - AFA - BANANA, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '9.758,68',
#   'PRECIO UNITARIO CON IVA': '11.808,00'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'MAXI GAIN - AFA- BANANA, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '1.250',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'MAXI GAIN - AFA- BANANA, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '14.638,02',
#   'PRECIO UNITARIO CON IVA': '17.712,00'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'MAXI GAIN - AFA- BANANA, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': 'FRASCO - 90 CAPSULAS',
#   'CONTENIDO NETO': '41',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'MAXI GAIN - AFA- BANANA, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '7.711,74',
#   'PRECIO UNITARIO CON IVA': '9.331,20'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'MAXI GAIN - AFA- BANANA, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': 'FRASCO - 60 CAPSULAS',
#   'CONTENIDO NETO': '30',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'MAXI GAIN - AFA- BANANA, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '7.235,70',
#   'PRECIO UNITARIO CON IVA': '8.755,20'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'T.N.T. (TOTAL NITRIC TECNOLOGY) - FRUTOS DEL BOSQUE - KOSHER',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '500',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'T.N.T. (TOTAL NITRIC TECNOLOGY) - FRUTOS DEL BOSQUE - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '11.377,19',
#   'PRECIO UNITARIO CON IVA': '13.766,40'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'WHEY PROTEIN 7900 - AFA - BANANA, CAPUCCINO, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '500',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'WHEY PROTEIN 7900 - AFA - BANANA, CAPUCCINO, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '14.280,99',
#   'PRECIO UNITARIO CON IVA': '17.280,00'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'WHEY PROTEIN 7900 - AFA - CHOCOLATE, DULCE DE LECHE, VAINILLA',
#   'PRESENTACIÓN': 'POTE - POLVO',
#   'CONTENIDO NETO': '908',
#   'CANTIDAD POR BULTO': '6',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'WHEY PROTEIN 7900 - AFA - CHOCOLATE, DULCE DE LECHE, VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '25.943,80',
#   'PRECIO UNITARIO CON IVA': '31.392,00'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'WHEY PROTEIN 7900 - AFA - BANANA, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '1.000',
#   'CANTIDAD POR BULTO': '10',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'WHEY PROTEIN 7900 - AFA - BANANA, CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '25.705,79',
#   'PRECIO UNITARIO CON IVA': '31.104,00'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'WHEY PROTEIN 7900 - AFA - CHOCOLATE, VAINILLA',
#   'PRESENTACIÓN': 'BALDE - POLVO',
#   'CONTENIDO NETO': '3.000',
#   'CANTIDAD POR BULTO': '1',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ALTO RENDIMIENTO',
#   'DESCRIPCIÓN': 'WHEY PROTEIN 7900 - AFA - CHOCOLATE, VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '73.309,09',
#   'PRECIO UNITARIO CON IVA': '88.704,00'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'E.H.P.O. (ENDURANCE HIGH PERFORMANCE OBJETIVE) - ANANA',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '500',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'E.H.P.O. (ENDURANCE HIGH PERFORMANCE OBJETIVE) - ANANA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '10.472,73',
#   'PRECIO UNITARIO CON IVA': '12.672,00'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'L-CARNITINE LIQUID - KOSHER',
#   'PRESENTACIÓN': 'FRASCO - 500 ml',
#   'CONTENIDO NETO': '500',
#   'CANTIDAD POR BULTO': '25',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'L-CARNITINE LIQUID - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '8.044,96',
#   'PRECIO UNITARIO CON IVA': '9.734,40'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'NITRIC WHEY - VAINILLA',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '500',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'NITRIC WHEY - VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '14.757,02',
#   'PRECIO UNITARIO CON IVA': '17.856,00'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'NITRIC WHEY - VAINILLA',
#   'PRESENTACIÓN': 'FRASCO - 60 CAPSULAS',
#   'CONTENIDO NETO': '48',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'NITRIC WHEY - VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '12.614,88',
#   'PRECIO UNITARIO CON IVA': '15.264,00'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'VOLCANO EXTREME - FRUTOS DEL BOSQUE',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '1.200',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'VOLCANO EXTREME - FRUTOS DEL BOSQUE',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '21.897,52',
#   'PRECIO UNITARIO CON IVA': '26.496,00'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'WHEY PROTEIN PREMIUM - CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '500',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'WHEY PROTEIN PREMIUM - CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '14.757,02',
#   'PRECIO UNITARIO CON IVA': '17.856,00'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'WHEY PROTEIN PREMIUM - CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '1.000',
#   'CANTIDAD POR BULTO': '10',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'PREMIUM',
#   'DESCRIPCIÓN': 'WHEY PROTEIN PREMIUM - CHOCOLATE, FRUTILLA, VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '26.562,64',
#   'PRECIO UNITARIO CON IVA': '32.140,80'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON BAR - AFA - BANANA, CHOCOLATE, COCO, COOKIES & CREAM, DULCE DE LECHE,',
#   'PRESENTACIÓN': 'DISPLAY - 20 UNIDADES',
#   'CONTENIDO NETO': '920',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON BAR - AFA - BANANA, CHOCOLATE, COCO, COOKIES & CREAM, DULCE DE LECHE,',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '21.897,52',
#   'PRECIO UNITARIO CON IVA': '26.496,00'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'FRUTILLA, MENTA GRANIZADA, LEMON COOKIE',
#   'PRESENTACIÓN': 'DISPLAY - 12 UNIDADES',
#   'CONTENIDO NETO': '552',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'FRUTILLA, MENTA GRANIZADA, LEMON COOKIE',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '13.138,51',
#   'PRECIO UNITARIO CON IVA': '15.897,60'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON DRINK ISOTONIC HYDRATATION GREEN APPLE FLAVOUR - AFA',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '400',
#   'CANTIDAD POR BULTO': '6',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON DRINK ISOTONIC HYDRATATION GREEN APPLE FLAVOUR - AFA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '9.520,66',
#   'PRECIO UNITARIO CON IVA': '11.520,00'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON FULL RECOVERY - AFA - FRUTOS DEL BOSQUE - KOSHER',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '500',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON FULL RECOVERY - AFA - FRUTOS DEL BOSQUE - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '8.806,61',
#   'PRECIO UNITARIO CON IVA': '10.656,00'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON GEL - AFA - BANANA, FRUTILLA, LIMÓN, VAINILLA - KOSHER',
#   'PRESENTACIÓN': 'DISPLAY - 24 UNIDADES',
#   'CONTENIDO NETO': '480',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON GEL - AFA - BANANA, FRUTILLA, LIMÓN, VAINILLA - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '13.709,75',
#   'PRECIO UNITARIO CON IVA': '16.588,80'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON GEL BCAA - AFA - GREEN APPLE - DELICIOUS COCOA',
#   'PRESENTACIÓN': 'DISPLAY - 6 UNIDADES',
#   'CONTENIDO NETO': '120',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON GEL BCAA - AFA - GREEN APPLE - DELICIOUS COCOA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '3.855,87',
#   'PRECIO UNITARIO CON IVA': '4.665,60'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON GEL BCAA - AFA - GREEN APPLE - DELICIOUS COCOA',
#   'PRESENTACIÓN': 'DISPLAY - 6 UNIDADES',
#   'CONTENIDO NETO': '120',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON GEL BCAA - AFA - GREEN APPLE - DELICIOUS COCOA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '3.855,87',
#   'PRECIO UNITARIO CON IVA': '4.665,60'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON GEL CON CAFEINA - AFA - FRUTOS DEL BOSQUE, LIMA-LIMON, TURBO COFFE',
#   'PRESENTACIÓN': 'DISPLAY - 24 UNIDADES',
#   'CONTENIDO NETO': '480',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'IRON',
#   'DESCRIPCIÓN': 'IRON GEL CON CAFEINA - AFA - FRUTOS DEL BOSQUE, LIMA-LIMON, TURBO COFFE',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '13.709,75',
#   'PRECIO UNITARIO CON IVA': '16.588,80'},
#  {'Categoria': 'BEAUTY',
#   'DESCRIPCIÓN': 'COLLAGEN BAR - CHOCOLATE',
#   'PRESENTACIÓN': 'DISPLAY - 10 UNIDADES',
#   'CONTENIDO NETO': '450',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'BEAUTY',
#   'DESCRIPCIÓN': 'COLLAGEN BAR - CHOCOLATE',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '11.424,79',
#   'PRECIO UNITARIO CON IVA': '13.824,00'},
#  {'Categoria': 'BEAUTY',
#   'DESCRIPCIÓN': 'COLLAGEN BEBIBLE - BLUEBERRY',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '360',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'BEAUTY',
#   'DESCRIPCIÓN': 'COLLAGEN BEBIBLE - BLUEBERRY',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '15.709,09',
#   'PRECIO UNITARIO CON IVA': '19.008,00'},
#  {'Categoria': 'BEAUTY',
#   'DESCRIPCIÓN': 'COLLAGEN BEBIBLE - BLUEBERRY',
#   'PRESENTACIÓN': 'DISPLAY x 30 SOBRES',
#   'CONTENIDO NETO': '360',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'BEAUTY',
#   'DESCRIPCIÓN': 'COLLAGEN BEBIBLE - BLUEBERRY',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '18.089,26',
#   'PRECIO UNITARIO CON IVA': '21.888,00'},
#  {'Categoria': 'BEAUTY',
#   'DESCRIPCIÓN': 'LIPOLITIC CLA 1000',
#   'PRESENTACIÓN': 'FRASCO - 60 CAPSULAS',
#   'CONTENIDO NETO': '30',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'BEAUTY',
#   'DESCRIPCIÓN': 'LIPOLITIC CLA 1000',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '8.806,61',
#   'PRECIO UNITARIO CON IVA': '10.656,00'},
#  {'Categoria': 'BEAUTY',
#   'DESCRIPCIÓN': 'PRE WORKOUT WILD RED BERRIES',
#   'PRESENTACIÓN': 'POTE - POLVO',
#   'CONTENIDO NETO': '400',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'BEAUTY',
#   'DESCRIPCIÓN': 'PRE WORKOUT WILD RED BERRIES',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '20.231,40',
#   'PRECIO UNITARIO CON IVA': '24.480,00'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'KETO CRACKERS LOW CARB  - AFA - PIZZA FLAVOUR, NATURAL FLAVOUR',
#   'PRESENTACIÓN': '1 BOLSITA INDIVIDUAL',
#   'CONTENIDO NETO': '33',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'KETO CRACKERS LOW CARB  - AFA - PIZZA FLAVOUR, NATURAL FLAVOUR',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '1.999,34',
#   'PRECIO UNITARIO CON IVA': '2.419,20'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'GLUTAMINA MICRONIZADA - AFA - KOSHER',
#   'PRESENTACIÓN': 'POTE - POLVO',
#   'CONTENIDO NETO': '300',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'GLUTAMINA MICRONIZADA - AFA - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '18.089,26',
#   'PRECIO UNITARIO CON IVA': '21.888,00'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'MULTIVITAMIN - KOSHER',
#   'PRESENTACIÓN': 'FRASCO - 60 COMPRIMIDOS',
#   'CONTENIDO NETO': '72',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'MULTIVITAMIN - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '6.664,46',
#   'PRECIO UNITARIO CON IVA': '8.064,00'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'OMEGA 3 EPA FISH OIL - KOSHER',
#   'PRESENTACIÓN': 'FRASCO - 60 CAPSULAS BLANDAS',
#   'CONTENIDO NETO': '84',
#   'CANTIDAD POR BULTO': '25',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'OMEGA 3 EPA FISH OIL - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '19.993,39',
#   'PRECIO UNITARIO CON IVA': '24.192,00'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'OMELETTE PROTEIN - JAMON Y QUESO, PIZZA',
#   'PRESENTACIÓN': 'DISPLAY x 7 SOBRES',
#   'CONTENIDO NETO': '182',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'OMELETTE PROTEIN - JAMON Y QUESO, PIZZA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '9.996,69',
#   'PRECIO UNITARIO CON IVA': '12.096,00'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'ONE WEEK WHEY PROTEIN 7900 - CHOCOLATE, VAINILLA',
#   'PRESENTACIÓN': 'DISPLAY - 7 SOBRES',
#   'CONTENIDO NETO': '175',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'ONE WEEK WHEY PROTEIN 7900 - CHOCOLATE, VAINILLA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '7.687,93',
#   'PRECIO UNITARIO CON IVA': '9.302,40'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'PROTEIN BAR LOW CARB - CHOCOLATE BROWNIE, PEANUT BUTTER, RASPBERRY',
#   'PRESENTACIÓN': 'DISPLAY - 10 UNIDADES',
#   'CONTENIDO NETO': '450',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'PROTEIN BAR LOW CARB - CHOCOLATE BROWNIE, PEANUT BUTTER, RASPBERRY',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '15.233,06',
#   'PRECIO UNITARIO CON IVA': '18.432,00'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'WAKE BREAK WHEY PROTEIN 7900 - CAFÉ CAPUCCINO',
#   'PRESENTACIÓN': 'POTE - POLVO',
#   'CONTENIDO NETO': '1.130',
#   'CANTIDAD POR BULTO': '6',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'WAKE BREAK WHEY PROTEIN 7900 - CAFÉ CAPUCCINO',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '30.942,15',
#   'PRECIO UNITARIO CON IVA': '37.440,00'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'ZMA RECOVERY TESTO FORMULA',
#   'PRESENTACIÓN': 'FRASCO - 60 CAPSULAS',
#   'CONTENIDO NETO': '27',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'NUTRICION',
#   'DESCRIPCIÓN': 'ZMA RECOVERY TESTO FORMULA',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '6.902,48',
#   'PRECIO UNITARIO CON IVA': '8.352,00'},
#  {'Categoria': 'KIDS',
#   'DESCRIPCIÓN': 'BARRA DOM DESAYUNO O MERIENDA - CHOCOLATE',
#   'PRESENTACIÓN': 'DISPLAY - 12 UNIDADES',
#   'CONTENIDO NETO': '312',
#   'CANTIDAD POR BULTO': '20',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'KIDS',
#   'DESCRIPCIÓN': 'BARRA DOM DESAYUNO O MERIENDA - CHOCOLATE',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '6.664,46',
#   'PRECIO UNITARIO CON IVA': '8.064,00'},
#  {'Categoria': 'VEGGIE PLANT BASED',
#   'DESCRIPCIÓN': 'PLANT BASED PROTEIN BAR VEGGIE BAR - CACAO, PEANUT BUTTER - KOSHER',
#   'PRESENTACIÓN': 'DISPLAY - 10 UNIDADES',
#   'CONTENIDO NETO': '600',
#   'CANTIDAD POR BULTO': '24',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'VEGGIE PLANT BASED',
#   'DESCRIPCIÓN': 'PLANT BASED PROTEIN BAR VEGGIE BAR - CACAO, PEANUT BUTTER - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '14.757,02',
#   'PRECIO UNITARIO CON IVA': '17.856,00'},
#  {'Categoria': 'VEGGIE PLANT BASED',
#   'DESCRIPCIÓN': 'PLANT BASED VEGGIE SHAKE PROTEIN - CACAO - KOSHER',
#   'PRESENTACIÓN': 'DOYPACK - POLVO',
#   'CONTENIDO NETO': '500',
#   'CANTIDAD POR BULTO': '12',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'VEGGIE PLANT BASED',
#   'DESCRIPCIÓN': 'PLANT BASED VEGGIE SHAKE PROTEIN - CACAO - KOSHER',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '14.995,04',
#   'PRECIO UNITARIO CON IVA': '18.144,00'},
#  {'Categoria': 'ACCESORIOS',
#   'DESCRIPCIÓN': 'BANDA ELASTICA - HEAVY, MEDIUM, LOW',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '1',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ACCESORIOS',
#   'DESCRIPCIÓN': 'BANDA ELASTICA - HEAVY, MEDIUM, LOW',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '4.760,33',
#   'PRECIO UNITARIO CON IVA': '5.760,00'},
#  {'Categoria': 'ACCESORIOS',
#   'DESCRIPCIÓN': 'BANDA ELASTICA - HEAVY, MEDIUM, LOW',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '50',
#   'PRECIO UNITARIO NETO': '$',
#   'PRECIO UNITARIO CON IVA': '$'},
#  {'Categoria': 'ACCESORIOS',
#   'DESCRIPCIÓN': 'BANDA ELASTICA - HEAVY, MEDIUM, LOW',
#   'PRESENTACIÓN': '',
#   'CONTENIDO NETO': '',
#   'CANTIDAD POR BULTO': '',
#   'PRECIO UNITARIO NETO': '6.426,45',
#   'PRECIO UNITARIO CON IVA': '7.776,00'}]

# %%
pdf_path = 'LISTA DE PRECIOS MAYORISTA - GENTECH - SEPTIEMBRE 2025.pdf'
tables = camelot.read_pdf(pdf_path, flavor='hybrid', pages='1', table_areas=['50,780,800,0'])
# Out:
# d:\Users\juanp_schamun\AppData\Local\anaconda3\envs\pdf_env\lib\site-packages\camelot\parsers\hybrid.py:161: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   table.df = table.df.replace("", np.nan)

# %%
tables[0].df.head(20)
# Out:
#                                                     0  \
# 0
# 1
# 2
# 3
# 4                                          AMINO 7600
# 5
# 6              AMINO 9000 - DULCE DE LECHE / FRUTILLA
# 7                                           BCAA 4000
# 8   C.D.S. (CREATINE DELIVERY SYSTEM) - FRUTAS TRO...
# 9                                           CARNITINA
# 10                               CARTÍLAGO DE TIBURÓN
# 11                     CREATINA MASTICABLE - FRUTILLA
# 12                CREATINA MONOHIDRATO - AFA - KOSHER
# 13                CREATINA MONOHIDRATO - AFA - KOSHER
# 14                                    HIGH DEFINITION
# 15  MAXI GAIN - AFA - BANANA, CHOCOLATE, FRUTILLA,...
# 16  MAXI GAIN - AFA- BANANA, CHOCOLATE, FRUTILLA, ...
# 17                                       NITRIC OXIDE
# 18                                      RIPPED MAX II
# 19  T.N.T. (TOTAL NITRIC TECNOLOGY) - FRUTOS DEL B...
#
#                            2            3          4                        5  \
# 0                             NETO GRAMOS  POR BULTO            UNITARIO NETO
# 1
# 2     LINEA ALTO RENDIMIENTO
# 3      POTE -150 COMPRIMIDOS          285         12   $          \n11.424,79
# 4
# 5     POTE - 325 COMPRIMIDOS          618         12   $          \n22.849,59
# 6   DOYPACK -160 COMPRIMIDOS          480         12   $          \n13.566,94
# 7   FRASCO - 120 COMPRIMIDOS          168         24  $            \n8.759,01
# 8            DOYPACK - POLVO          800         12   $          \n12.472,07
# 9       FRASCO - 90 CAPSULAS           41         24  $            \n7.521,32
# 10   FRASCO - 60 COMPRIMIDOS           72         24  $            \n6.188,43
# 11     POTE -150 COMPRIMIDOS          437         12   $          \n13.519,34
# 12           DOYPACK - POLVO          250         12   $          \n16.232,73
# 13           DOYPACK - POLVO          500         12   $          \n29.038,02
# 14     FRASCO - 120 CAPSULAS           54         24  $            \n8.235,37
# 15           DOYPACK - POLVO          750         12  $            \n9.758,68
# 16           DOYPACK - POLVO        1.250         12   $          \n14.638,02
# 17      FRASCO - 90 CAPSULAS           41         24  $            \n7.711,74
# 18      FRASCO - 60 CAPSULAS           30         24  $            \n7.235,70
# 19           DOYPACK - POLVO          500         12   $          \n11.377,19
#
#                           6
# 0
# 1                       IVA
# 2
# 3    $          \n13.824,00
# 4
# 5    $          \n27.648,00
# 6    $          \n16.416,00
# 7    $          \n10.598,40
# 8    $          \n15.091,20
# 9   $            \n9.100,80
# 10  $            \n7.488,00
# 11   $          \n16.358,40
# 12   $          \n19.641,60
# 13   $          \n35.136,00
# 14  $            \n9.964,80
# 15   $          \n11.808,00
# 16   $          \n17.712,00
# 17  $            \n9.331,20
# 18  $            \n8.755,20
# 19   $          \n13.766,40

# %%
pdf_path = 'LISTA DE PRECIOS MAYORISTA - GENTECH - SEPTIEMBRE 2025.pdf'
tables = camelot.read_pdf(pdf_path, flavor='hybrid', pages='1', table_areas=['50,780,800,0'])


df = tables[0].df.copy()

# Limpiar los datos de la tabla, eliminando espacios extra
df = df.map(lambda x: str(x).strip() if isinstance(x, str) else x)

# Eliminar filas completamente vacías
df.dropna(how='all', inplace=True)

# Eliminar la fila de encabezado que a veces se extrae
df = df[~df.iloc[:, 0].str.contains('DESCRIPCIÓN', na=False)]

# Reorganizar los encabezados y datos
df.columns = ['DESCRIPCIÓN', 'PRESENTACIÓN', 'CONTENIDO NETO', 'CANTIDAD POR BULTO', 'PRECIO UNITARIO NETO', 'PRECIO UNITARIO CON IVA']

df.head(20)
# Out:
# d:\Users\juanp_schamun\AppData\Local\anaconda3\envs\pdf_env\lib\site-packages\camelot\parsers\hybrid.py:161: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   table.df = table.df.replace("", np.nan)
#                                           DESCRIPCIÓN  \
# 0
# 1
# 2
# 3
# 4                                          AMINO 7600
# 5
# 6              AMINO 9000 - DULCE DE LECHE / FRUTILLA
# 7                                           BCAA 4000
# 8   C.D.S. (CREATINE DELIVERY SYSTEM) - FRUTAS TRO...
# 9                                           CARNITINA
# 10                               CARTÍLAGO DE TIBURÓN
# 11                     CREATINA MASTICABLE - FRUTILLA
# 12                CREATINA MONOHIDRATO - AFA - KOSHER
# 13                CREATINA MONOHIDRATO - AFA - KOSHER
# 14                                    HIGH DEFINITION
# 15  MAXI GAIN - AFA - BANANA, CHOCOLATE, FRUTILLA,...
# 16  MAXI GAIN - AFA- BANANA, CHOCOLATE, FRUTILLA, ...
# 17                                       NITRIC OXIDE
# 18                                      RIPPED MAX II
# 19  T.N.T. (TOTAL NITRIC TECNOLOGY) - FRUTOS DEL B...
#
#                 PRESENTACIÓN CONTENIDO NETO CANTIDAD POR BULTO  \
# 0                               NETO GRAMOS          POR BULTO
# 1
# 2     LINEA ALTO RENDIMIENTO
# 3      POTE -150 COMPRIMIDOS            285                 12
# 4
# 5     POTE - 325 COMPRIMIDOS            618                 12
# 6   DOYPACK -160 COMPRIMIDOS            480                 12
# 7   FRASCO - 120 COMPRIMIDOS            168                 24
# 8            DOYPACK - POLVO            800                 12
# 9       FRASCO - 90 CAPSULAS             41                 24
# 10   FRASCO - 60 COMPRIMIDOS             72                 24
# 11     POTE -150 COMPRIMIDOS            437                 12
# 12           DOYPACK - POLVO            250                 12
# 13           DOYPACK - POLVO            500                 12
# 14     FRASCO - 120 CAPSULAS             54                 24
# 15           DOYPACK - POLVO            750                 12
# 16           DOYPACK - POLVO          1.250                 12
# 17      FRASCO - 90 CAPSULAS             41                 24
# 18      FRASCO - 60 CAPSULAS             30                 24
# 19           DOYPACK - POLVO            500                 12
#
#        PRECIO UNITARIO NETO  PRECIO UNITARIO CON IVA
# 0             UNITARIO NETO
# 1                                                IVA
# 2
# 3    $          \n11.424,79   $          \n13.824,00
# 4
# 5    $          \n22.849,59   $          \n27.648,00
# 6    $          \n13.566,94   $          \n16.416,00
# 7   $            \n8.759,01   $          \n10.598,40
# 8    $          \n12.472,07   $          \n15.091,20
# 9   $            \n7.521,32  $            \n9.100,80
# 10  $            \n6.188,43  $            \n7.488,00
# 11   $          \n13.519,34   $          \n16.358,40
# 12   $          \n16.232,73   $          \n19.641,60
# 13   $          \n29.038,02   $          \n35.136,00
# 14  $            \n8.235,37  $            \n9.964,80
# 15  $            \n9.758,68   $          \n11.808,00
# 16   $          \n14.638,02   $          \n17.712,00
# 17  $            \n7.711,74  $            \n9.331,20
# 18  $            \n7.235,70  $            \n8.755,20
# 19   $          \n11.377,19   $          \n13.766,40

# %%
import re

# Suponiendo que 'df' es el DataFrame resultante de tu código anterior
# df = tables[0].df.copy()
# ... (código de limpieza previo)

# PASO 1: Identificar las filas de categoría y crear una nueva columna
df['Categoria'] = None
current_category = ''

# Iterar sobre las filas y asignar la categoría a los productos subsiguientes
for index, row in df.iterrows():
    # Detectar la fila de categoría usando el texto
    row_values_str = ' '.join(str(val) for val in row.tolist()).upper()
    category_keywords = ['LINEA ALTO RENDIMIENTO', 'LINEA PREMIUM', 'LINEA IRON', 'LINEA BEAUTY', 'LINEA PRE_WORKOUT', 'LINEA NUTRICION',
                         'LINEA KIDS', 'LINEA VEGGIE PLANT BASED', 'ACCESORIOS']
    
    is_category_row = any(keyword in row_values_str for keyword in category_keywords)
    
    if is_category_row:
        # Extraer el nombre de la categoría y guardarlo
        category_name = next((val for val in row.tolist() if str(val).strip()), None)
        if category_name:
            # Eliminar la palabra "LINEA" para un nombre más limpio
            current_category = re.sub(r'(LÍNEA|LINEA)\s*', '', str(category_name), flags=re.IGNORECASE).strip()
    else:
        # Asignar la categoría guardada a las filas de productos
        df.at[index, 'Categoria'] = current_category

# PASO 2: Eliminar las filas de categoría originales basadas en la nueva lógica
# La fila se elimina si contiene una palabra clave de categoría y el campo de "DESCRIPCIÓN" está vacío.
rows_to_keep = []
for index, row in df.iterrows():
    # Verificar si el campo "DESCRIPCIÓN" de la fila no está vacío
    is_product_row = str(row['DESCRIPCIÓN']).strip() != ''

    # Si es una fila de producto (con una descripción), la mantenemos
    if is_product_row:
        rows_to_keep.append(True)
    else:
        # Si la descripción está vacía, verificamos si contiene una palabra clave de categoría
        row_values_str = ' '.join(str(val) for val in row.tolist()).upper()
        is_category_row = any(keyword in row_values_str for keyword in category_keywords)

        # Si no es una fila de categoría, la mantenemos, ya que podría ser un sub-producto
        if not is_category_row:
            rows_to_keep.append(True)
        else:
            rows_to_keep.append(False)

df_processed = df[rows_to_keep][2:].copy()

# Opcional: Reordenar las columnas para que 'Categoria' esté al inicio
column_order = ['Categoria'] + [col for col in df_processed.columns if col != 'Categoria']
df_processed = df_processed[column_order]

# Ahora, df_processed es el DataFrame con la columna 'Categoria' y sin las filas de categoría.

df_processed.head(40)
# Out:
#            Categoria                                        DESCRIPCIÓN  \
# 3   ALTO RENDIMIENTO
# 4   ALTO RENDIMIENTO                                         AMINO 7600
# 5   ALTO RENDIMIENTO
# 6   ALTO RENDIMIENTO             AMINO 9000 - DULCE DE LECHE / FRUTILLA
# 7   ALTO RENDIMIENTO                                          BCAA 4000
# 8   ALTO RENDIMIENTO  C.D.S. (CREATINE DELIVERY SYSTEM) - FRUTAS TRO...
# 9   ALTO RENDIMIENTO                                          CARNITINA
# 10  ALTO RENDIMIENTO                               CARTÍLAGO DE TIBURÓN
# 11  ALTO RENDIMIENTO                     CREATINA MASTICABLE - FRUTILLA
# 12  ALTO RENDIMIENTO                CREATINA MONOHIDRATO - AFA - KOSHER
# 13  ALTO RENDIMIENTO                CREATINA MONOHIDRATO - AFA - KOSHER
# 14  ALTO RENDIMIENTO                                    HIGH DEFINITION
# 15  ALTO RENDIMIENTO  MAXI GAIN - AFA - BANANA, CHOCOLATE, FRUTILLA,...
# 16  ALTO RENDIMIENTO  MAXI GAIN - AFA- BANANA, CHOCOLATE, FRUTILLA, ...
# 17  ALTO RENDIMIENTO                                       NITRIC OXIDE
# 18  ALTO RENDIMIENTO                                      RIPPED MAX II
# 19  ALTO RENDIMIENTO  T.N.T. (TOTAL NITRIC TECNOLOGY) - FRUTOS DEL B...
# 20  ALTO RENDIMIENTO  WHEY PROTEIN 7900 - AFA - BANANA, CAPUCCINO, C...
# 21  ALTO RENDIMIENTO  WHEY PROTEIN 7900 - AFA - CHOCOLATE, DULCE DE ...
# 22  ALTO RENDIMIENTO  WHEY PROTEIN 7900 - AFA - BANANA, CHOCOLATE, F...
# 23  ALTO RENDIMIENTO      WHEY PROTEIN 7900 - AFA - CHOCOLATE, VAINILLA
# 25           PREMIUM  E.H.P.O. (ENDURANCE HIGH PERFORMANCE OBJETIVE)...
# 26           PREMIUM                        L-CARNITINE LIQUID - KOSHER
# 27           PREMIUM                             NITRIC WHEY - VAINILLA
# 28           PREMIUM                                     TX3 BLACK CUTS
# 29           PREMIUM                VOLCANO EXTREME - FRUTOS DEL BOSQUE
# 30           PREMIUM  WHEY PROTEIN PREMIUM - CHOCOLATE, FRUTILLA, VA...
# 31           PREMIUM  WHEY PROTEIN PREMIUM - CHOCOLATE, FRUTILLA, VA...
# 33              IRON  IRON BAR - AFA - BANANA, CHOCOLATE, COCO, COOK...
# 34              IRON            FRUTILLA, MENTA GRANIZADA, LEMON COOKIE
# 35              IRON  IRON DRINK ISOTONIC HYDRATATION GREEN APPLE FL...
# 36              IRON  IRON FULL RECOVERY - AFA - FRUTOS DEL BOSQUE -...
# 37              IRON  IRON GEL - AFA - BANANA, FRUTILLA, LIMÓN, VAIN...
# 38              IRON  IRON GEL BCAA - AFA - GREEN APPLE - DELICIOUS ...
# 39              IRON
# 40              IRON  IRON GEL CON CAFEINA - AFA - FRUTOS DEL BOSQUE...
# 41              IRON
# 43            BEAUTY                           COLLAGEN BAR - CHOCOLATE
# 44            BEAUTY                       COLLAGEN BEBIBLE - BLUEBERRY
# 45            BEAUTY                       COLLAGEN BEBIBLE - BLUEBERRY
#
#                 PRESENTACIÓN CONTENIDO NETO CANTIDAD POR BULTO  \
# 3      POTE -150 COMPRIMIDOS            285                 12
# 4
# 5     POTE - 325 COMPRIMIDOS            618                 12
# 6   DOYPACK -160 COMPRIMIDOS            480                 12
# 7   FRASCO - 120 COMPRIMIDOS            168                 24
# 8            DOYPACK - POLVO            800                 12
# 9       FRASCO - 90 CAPSULAS             41                 24
# 10   FRASCO - 60 COMPRIMIDOS             72                 24
# 11     POTE -150 COMPRIMIDOS            437                 12
# 12           DOYPACK - POLVO            250                 12
# 13           DOYPACK - POLVO            500                 12
# 14     FRASCO - 120 CAPSULAS             54                 24
# 15           DOYPACK - POLVO            750                 12
# 16           DOYPACK - POLVO          1.250                 12
# 17      FRASCO - 90 CAPSULAS             41                 24
# 18      FRASCO - 60 CAPSULAS             30                 24
# 19           DOYPACK - POLVO            500                 12
# 20           DOYPACK - POLVO            500                 12
# 21              POTE - POLVO            908                  6
# 22           DOYPACK - POLVO          1.000                 10
# 23             BALDE - POLVO          3.000                  1
# 25           DOYPACK - POLVO            500                 12
# 26           FRASCO - 500 ml            500                 25
# 27           DOYPACK - POLVO            500                 12
# 28      FRASCO - 60 CAPSULAS             48                 24
# 29           DOYPACK - POLVO          1.200                 12
# 30           DOYPACK - POLVO            500                 12
# 31           DOYPACK - POLVO          1.000                 10
# 33     DISPLAY - 20 UNIDADES            920                 12
# 34     DISPLAY - 12 UNIDADES            552                 12
# 35           DOYPACK - POLVO            400                  6
# 36           DOYPACK - POLVO            500                 24
# 37     DISPLAY - 24 UNIDADES            480                 12
# 38      DISPLAY - 6 UNIDADES            120                 24
# 39      DISPLAY - 6 UNIDADES            120                 24
# 40
# 41     DISPLAY - 24 UNIDADES            480                 12
# 43     DISPLAY - 10 UNIDADES            450                 24
# 44           DOYPACK - POLVO            360                 24
# 45       DISPLAY x 30 SOBRES            360                 12
#
#        PRECIO UNITARIO NETO  PRECIO UNITARIO CON IVA
# 3    $          \n11.424,79   $          \n13.824,00
# 4
# 5    $          \n22.849,59   $          \n27.648,00
# 6    $          \n13.566,94   $          \n16.416,00
# 7   $            \n8.759,01   $          \n10.598,40
# 8    $          \n12.472,07   $          \n15.091,20
# 9   $            \n7.521,32  $            \n9.100,80
# 10  $            \n6.188,43  $            \n7.488,00
# 11   $          \n13.519,34   $          \n16.358,40
# 12   $          \n16.232,73   $          \n19.641,60
# 13   $          \n29.038,02   $          \n35.136,00
# 14  $            \n8.235,37  $            \n9.964,80
# 15  $            \n9.758,68   $          \n11.808,00
# 16   $          \n14.638,02   $          \n17.712,00
# 17  $            \n7.711,74  $            \n9.331,20
# 18  $            \n7.235,70  $            \n8.755,20
# 19   $          \n11.377,19   $          \n13.766,40
# 20   $          \n14.280,99   $          \n17.280,00
# 21   $          \n25.943,80   $          \n31.392,00
# 22   $          \n25.705,79   $          \n31.104,00
# 23   $          \n73.309,09   $          \n88.704,00
# 25   $          \n10.472,73   $          \n12.672,00
# 26  $            \n8.044,96  $            \n9.734,40
# 27   $          \n14.757,02   $          \n17.856,00
# 28   $          \n12.614,88   $          \n15.264,00
# 29   $          \n21.897,52   $          \n26.496,00
# 30   $          \n14.757,02   $          \n17.856,00
# 31   $          \n26.562,64   $          \n32.140,80
# 33   $          \n21.897,52   $          \n26.496,00
# 34   $          \n13.138,51   $          \n15.897,60
# 35  $            \n9.520,66   $          \n11.520,00
# 36  $            \n8.806,61   $          \n10.656,00
# 37   $          \n13.709,75   $          \n16.588,80
# 38  $            \n3.855,87  $            \n4.665,60
# 39  $            \n3.855,87  $            \n4.665,60
# 40
# 41   $          \n13.709,75   $          \n16.588,80
# 43   $          \n11.424,79   $          \n13.824,00
# 44   $          \n15.709,09   $          \n19.008,00
# 45   $          \n18.089,26   $          \n21.888,00

# %%
import pandas as pd
import re
import numpy as np

def procesarDf(df: pd.DataFrame) -> pd.DataFrame:
    """
    Limpia y procesa un DataFrame extraído de un PDF para estructurar los datos
    de productos y categorías.

    Esta función realiza los siguientes pasos:
    1. Limpia los datos eliminando espacios y filas vacías.
    2. Renombra las columnas para una mejor legibilidad.
    3. Propaga las descripciones de productos y las categorías a las filas correspondientes,
       manejando celdas combinadas y saltos de línea.
    4. Elimina las filas de categoría y cualquier otra fila irrelevante.
    5. Elimina las filas de producto que no pudieron ser categorizadas.
    6. Reordena las columnas para una presentación más lógica.

    Args:
        df (pd.DataFrame): El DataFrame original extraído directamente del PDF.

    Returns:
        pd.DataFrame: Un DataFrame limpio y estructurado con productos,
                      sus descripciones y categorías.
    """
    # 1. Limpieza inicial del DataFrame
    # Eliminar espacios extra de todas las celdas
    df = df.applymap(lambda x: str(x).strip() if isinstance(x, str) else x)

    # Eliminar filas que están completamente vacías
    df.dropna(how='all', inplace=True)

    # Eliminar la fila de encabezado que a veces se extrae
    df = df[~df.iloc[:, 0].str.contains('DESCRIPCIÓN', na=False)]

    # 2. Reorganizar los encabezados y datos
    df.columns = ['DESCRIPCIÓN', 'PRESENTACIÓN', 'CONTENIDO NETO', 'CANTIDAD POR BULTO', 'PRECIO UNITARIO NETO', 'PRECIO UNITARIO CON IVA']

    # 3. Propagación de descripciones de productos y categorías
    df_combined = df.copy()

    # Propagar las descripciones de productos, buscando tanto hacia adelante (ffill)
    # como hacia atrás (bfill) para manejar celdas combinadas.
    df_combined['temp_DESCRIPCIÓN'] = df_combined['DESCRIPCIÓN'].replace('', pd.NA).ffill().bfill()

    # Identificar y propagar las categorías.
    category_keywords = ['LINEA ALTO RENDIMIENTO', 'LINEA PREMIUM', 'LINEA IRON', 'LINEA BEAUTY', 'LINEA PRE_WORKOUT', 'LINEA NUTRICION',
                         'LINEA KIDS', 'LINEA VEGGIE PLANT BASED', 'ACCESORIOS']
    
    # Función para encontrar la categoría en una fila.
    def find_category(row):
        row_str = ' '.join(str(val) for val in row.tolist()).upper()
        for keyword in category_keywords:
            if keyword in row_str:
                cleaned_name = re.sub(r'(LÍNEA|LINEA)\s*', '', keyword, flags=re.IGNORECASE).strip()
                return cleaned_name
        return None

    df_combined['Categoria'] = df_combined.apply(find_category, axis=1)
    df_combined['Categoria'] = df_combined['Categoria'].replace('', pd.NA).ffill()

    # 4. Crear el DataFrame final y limpiar
    # Se filtra el DataFrame para incluir solo las filas con un precio válido.
    df_processed = df_combined[df_combined['PRECIO UNITARIO CON IVA'].apply(lambda x: str(x).strip() != '')].copy()

    # Asignar la descripción propagada a la columna principal.
    df_processed['DESCRIPCIÓN'] = df_processed['temp_DESCRIPCIÓN']

    # 5. Limpiar y reordenar el DataFrame final
    df_processed.drop(columns=['temp_DESCRIPCIÓN'], inplace=True)
    df_processed.reset_index(drop=True, inplace=True)

    # Eliminar las filas donde no se pudo asignar una categoría.
    df_processed = df_processed.dropna(subset=['Categoria'])
    df_processed.reset_index(drop=True, inplace=True)

    # Opcional: Reordenar las columnas.
    column_order = ['Categoria', 'DESCRIPCIÓN'] + [col for col in df_processed.columns if col not in ['Categoria', 'DESCRIPCIÓN']]
    df_processed = df_processed[column_order]

    return df_processed

# %%
pdf_path = 'LISTA DE PRECIOS MAYORISTA - GENTECH - SEPTIEMBRE 2025.pdf'
tables = camelot.read_pdf(pdf_path, flavor='hybrid', pages='1', table_areas=['50,780,800,0'])


df = tables[0].df.copy()

procesarDf(df)
# Out:
# d:\Users\juanp_schamun\AppData\Local\anaconda3\envs\pdf_env\lib\site-packages\camelot\parsers\hybrid.py:161: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   table.df = table.df.replace("", np.nan)
# D:\Users\juanp_schamun\AppData\Local\Temp\ipykernel_76340\1120024984.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: str(x).strip() if isinstance(x, str) else x)
#              Categoria                                        DESCRIPCIÓN  \
# 0     ALTO RENDIMIENTO                                         AMINO 7600
# 1     ALTO RENDIMIENTO                                         AMINO 7600
# 2     ALTO RENDIMIENTO             AMINO 9000 - DULCE DE LECHE / FRUTILLA
# 3     ALTO RENDIMIENTO                                          BCAA 4000
# 4     ALTO RENDIMIENTO  C.D.S. (CREATINE DELIVERY SYSTEM) - FRUTAS TRO...
# 5     ALTO RENDIMIENTO                                          CARNITINA
# 6     ALTO RENDIMIENTO                               CARTÍLAGO DE TIBURÓN
# 7     ALTO RENDIMIENTO                     CREATINA MASTICABLE - FRUTILLA
# 8     ALTO RENDIMIENTO                CREATINA MONOHIDRATO - AFA - KOSHER
# 9     ALTO RENDIMIENTO                CREATINA MONOHIDRATO - AFA - KOSHER
# 10    ALTO RENDIMIENTO                                    HIGH DEFINITION
# 11    ALTO RENDIMIENTO  MAXI GAIN - AFA - BANANA, CHOCOLATE, FRUTILLA,...
# 12    ALTO RENDIMIENTO  MAXI GAIN - AFA- BANANA, CHOCOLATE, FRUTILLA, ...
# 13    ALTO RENDIMIENTO                                       NITRIC OXIDE
# 14    ALTO RENDIMIENTO                                      RIPPED MAX II
# 15    ALTO RENDIMIENTO  T.N.T. (TOTAL NITRIC TECNOLOGY) - FRUTOS DEL B...
# 16    ALTO RENDIMIENTO  WHEY PROTEIN 7900 - AFA - BANANA, CAPUCCINO, C...
# 17    ALTO RENDIMIENTO  WHEY PROTEIN 7900 - AFA - CHOCOLATE, DULCE DE ...
# 18    ALTO RENDIMIENTO  WHEY PROTEIN 7900 - AFA - BANANA, CHOCOLATE, F...
# 19    ALTO RENDIMIENTO      WHEY PROTEIN 7900 - AFA - CHOCOLATE, VAINILLA
# 20             PREMIUM  E.H.P.O. (ENDURANCE HIGH PERFORMANCE OBJETIVE)...
# 21             PREMIUM                        L-CARNITINE LIQUID - KOSHER
# 22             PREMIUM                             NITRIC WHEY - VAINILLA
# 23             PREMIUM                                     TX3 BLACK CUTS
# 24             PREMIUM                VOLCANO EXTREME - FRUTOS DEL BOSQUE
# 25             PREMIUM  WHEY PROTEIN PREMIUM - CHOCOLATE, FRUTILLA, VA...
# 26             PREMIUM  WHEY PROTEIN PREMIUM - CHOCOLATE, FRUTILLA, VA...
# 27                IRON  IRON BAR - AFA - BANANA, CHOCOLATE, COCO, COOK...
# 28                IRON            FRUTILLA, MENTA GRANIZADA, LEMON COOKIE
# 29                IRON  IRON DRINK ISOTONIC HYDRATATION GREEN APPLE FL...
# 30                IRON  IRON FULL RECOVERY - AFA - FRUTOS DEL BOSQUE -...
# 31                IRON  IRON GEL - AFA - BANANA, FRUTILLA, LIMÓN, VAIN...
# 32                IRON  IRON GEL BCAA - AFA - GREEN APPLE - DELICIOUS ...
# 33                IRON  IRON GEL BCAA - AFA - GREEN APPLE - DELICIOUS ...
# 34                IRON  IRON GEL CON CAFEINA - AFA - FRUTOS DEL BOSQUE...
# 35              BEAUTY                           COLLAGEN BAR - CHOCOLATE
# 36              BEAUTY                       COLLAGEN BEBIBLE - BLUEBERRY
# 37              BEAUTY                       COLLAGEN BEBIBLE - BLUEBERRY
# 38              BEAUTY                                 LIPOLITIC CLA 1000
# 39              BEAUTY                       PRE WORKOUT WILD RED BERRIES
# 40           NUTRICION  KETO CRACKERS LOW CARB  - AFA - PIZZA FLAVOUR,...
# 41           NUTRICION               GLUTAMINA MICRONIZADA - AFA - KOSHER
# 42           NUTRICION                              MULTIVITAMIN - KOSHER
# 43           NUTRICION                      OMEGA 3 EPA FISH OIL - KOSHER
# 44           NUTRICION            OMELETTE PROTEIN - JAMON Y QUESO, PIZZA
# 45           NUTRICION   ONE WEEK WHEY PROTEIN 7900 - CHOCOLATE, VAINILLA
# 46           NUTRICION  PROTEIN BAR LOW CARB - CHOCOLATE BROWNIE, PEAN...
# 47           NUTRICION      WAKE BREAK WHEY PROTEIN 7900 - CAFÉ CAPUCCINO
# 48           NUTRICION                         ZMA RECOVERY TESTO FORMULA
# 49                KIDS          BARRA DOM DESAYUNO O MERIENDA - CHOCOLATE
# 50  VEGGIE PLANT BASED  PLANT BASED PROTEIN BAR VEGGIE BAR - CACAO, PE...
# 51  VEGGIE PLANT BASED  PLANT BASED VEGGIE SHAKE PROTEIN - CACAO - KOSHER
# 52          ACCESORIOS                BANDA ELASTICA - HEAVY, MEDIUM, LOW
# 53          ACCESORIOS                                             SHAKER
#
#                     PRESENTACIÓN CONTENIDO NETO CANTIDAD POR BULTO  \
# 0          POTE -150 COMPRIMIDOS            285                 12
# 1         POTE - 325 COMPRIMIDOS            618                 12
# 2       DOYPACK -160 COMPRIMIDOS            480                 12
# 3       FRASCO - 120 COMPRIMIDOS            168                 24
# 4                DOYPACK - POLVO            800                 12
# 5           FRASCO - 90 CAPSULAS             41                 24
# 6        FRASCO - 60 COMPRIMIDOS             72                 24
# 7          POTE -150 COMPRIMIDOS            437                 12
# 8                DOYPACK - POLVO            250                 12
# 9                DOYPACK - POLVO            500                 12
# 10         FRASCO - 120 CAPSULAS             54                 24
# 11               DOYPACK - POLVO            750                 12
# 12               DOYPACK - POLVO          1.250                 12
# 13          FRASCO - 90 CAPSULAS             41                 24
# 14          FRASCO - 60 CAPSULAS             30                 24
# 15               DOYPACK - POLVO            500                 12
# 16               DOYPACK - POLVO            500                 12
# 17                  POTE - POLVO            908                  6
# 18               DOYPACK - POLVO          1.000                 10
# 19                 BALDE - POLVO          3.000                  1
# 20               DOYPACK - POLVO            500                 12
# 21               FRASCO - 500 ml            500                 25
# 22               DOYPACK - POLVO            500                 12
# 23          FRASCO - 60 CAPSULAS             48                 24
# 24               DOYPACK - POLVO          1.200                 12
# 25               DOYPACK - POLVO            500                 12
# 26               DOYPACK - POLVO          1.000                 10
# 27         DISPLAY - 20 UNIDADES            920                 12
# 28         DISPLAY - 12 UNIDADES            552                 12
# 29               DOYPACK - POLVO            400                  6
# 30               DOYPACK - POLVO            500                 24
# 31         DISPLAY - 24 UNIDADES            480                 12
# 32          DISPLAY - 6 UNIDADES            120                 24
# 33          DISPLAY - 6 UNIDADES            120                 24
# 34         DISPLAY - 24 UNIDADES            480                 12
# 35         DISPLAY - 10 UNIDADES            450                 24
# 36               DOYPACK - POLVO            360                 24
# 37           DISPLAY x 30 SOBRES            360                 12
# 38          FRASCO - 60 CAPSULAS             30                 24
# 39                  POTE - POLVO            400                 24
# 40          1 BOLSITA INDIVIDUAL             33                 24
# 41                  POTE - POLVO            300                 12
# 42       FRASCO - 60 COMPRIMIDOS             72                 24
# 43  FRASCO - 60 CAPSULAS BLANDAS             84                 25
# 44            DISPLAY x 7 SOBRES            182                 24
# 45            DISPLAY - 7 SOBRES            175                 24
# 46         DISPLAY - 10 UNIDADES            450                 24
# 47                  POTE - POLVO          1.130                  6
# 48          FRASCO - 60 CAPSULAS             27                 24
# 49         DISPLAY - 12 UNIDADES            312                 20
# 50         DISPLAY - 10 UNIDADES            600                 24
# 51               DOYPACK - POLVO            500                 12
# 52                                                               1
# 53                                                              50
#
#        PRECIO UNITARIO NETO  PRECIO UNITARIO CON IVA
# 0    $          \n11.424,79   $          \n13.824,00
# 1    $          \n22.849,59   $          \n27.648,00
# 2    $          \n13.566,94   $          \n16.416,00
# 3   $            \n8.759,01   $          \n10.598,40
# 4    $          \n12.472,07   $          \n15.091,20
# 5   $            \n7.521,32  $            \n9.100,80
# 6   $            \n6.188,43  $            \n7.488,00
# 7    $          \n13.519,34   $          \n16.358,40
# 8    $          \n16.232,73   $          \n19.641,60
# 9    $          \n29.038,02   $          \n35.136,00
# 10  $            \n8.235,37  $            \n9.964,80
# 11  $            \n9.758,68   $          \n11.808,00
# 12   $          \n14.638,02   $          \n17.712,00
# 13  $            \n7.711,74  $            \n9.331,20
# 14  $            \n7.235,70  $            \n8.755,20
# 15   $          \n11.377,19   $          \n13.766,40
# 16   $          \n14.280,99   $          \n17.280,00
# 17   $          \n25.943,80   $          \n31.392,00
# 18   $          \n25.705,79   $          \n31.104,00
# 19   $          \n73.309,09   $          \n88.704,00
# 20   $          \n10.472,73   $          \n12.672,00
# 21  $            \n8.044,96  $            \n9.734,40
# 22   $          \n14.757,02   $          \n17.856,00
# 23   $          \n12.614,88   $          \n15.264,00
# 24   $          \n21.897,52   $          \n26.496,00
# 25   $          \n14.757,02   $          \n17.856,00
# 26   $          \n26.562,64   $          \n32.140,80
# 27   $          \n21.897,52   $          \n26.496,00
# 28   $          \n13.138,51   $          \n15.897,60
# 29  $            \n9.520,66   $          \n11.520,00
# 30  $            \n8.806,61   $          \n10.656,00
# 31   $          \n13.709,75   $          \n16.588,80
# 32  $            \n3.855,87  $            \n4.665,60
# 33  $            \n3.855,87  $            \n4.665,60
# 34   $          \n13.709,75   $          \n16.588,80
# 35   $          \n11.424,79   $          \n13.824,00
# 36   $          \n15.709,09   $          \n19.008,00
# 37   $          \n18.089,26   $          \n21.888,00
# 38  $            \n8.806,61   $          \n10.656,00
# 39   $          \n20.231,40   $          \n24.480,00
# 40  $            \n1.999,34  $            \n2.419,20
# 41   $          \n18.089,26   $          \n21.888,00
# 42  $            \n6.664,46  $            \n8.064,00
# 43   $          \n19.993,39   $          \n24.192,00
# 44  $            \n9.996,69   $          \n12.096,00
# 45  $            \n7.687,93  $            \n9.302,40
# 46   $          \n15.233,06   $          \n18.432,00
# 47   $          \n30.942,15   $          \n37.440,00
# 48  $            \n6.902,48  $            \n8.352,00
# 49  $            \n6.664,46  $            \n8.064,00
# 50   $          \n14.757,02   $          \n17.856,00
# 51   $          \n14.995,04   $          \n18.144,00
# 52  $            \n4.760,33  $            \n5.760,00
# 53  $            \n6.426,45  $            \n7.776,00

# %%
products = []
current_category = 'Sin Categoria'
last_product_desc = ""

for _, row in df.iterrows():
    row_values_str = ' '.join(str(val) for val in row.tolist()).upper()
    
    # Detectar las filas de categorías
    category_keywords = ['LINEA ALTO RENDIMIENTO', 'LINEA PREMIUM', 'LINEA IRON', 'LINEA BEAUTY', 'LINEA PRE_WORKOUT', 'LINEA NUTRICION',
                            'LINEA KIDS', 'LINEA VEGGIE PLANT BASED', 'ACCESORIOS']
    is_category_row = any(keyword in row_values_str for keyword in category_keywords)

    if is_category_row:
        category_name = next((val for val in row.tolist() if str(val).strip()), None)
        if category_name:
            cleaned_name = re.sub(r'(LÍNEA|LINEA)\s*', '', str(category_name), flags=re.IGNORECASE).strip()
            if cleaned_name.upper() not in ['DESCRIPCIÓN', 'PRESENTACIÓN', 'CONTENIDO NETO', 'CANTIDAD POR BULTO', 'PRECIO UNITARIO NETO', 'PRECIO UNITARIO CON IVA']:
                current_category = cleaned_name
        continue

# Si la fila tiene una descripción no vacía, es un producto principal
if str(row['DESCRIPCIÓN']).strip():
    last_product_desc = str(row['DESCRIPCIÓN'])

for _, row in df.iterrows():
    row_values_str = ' '.join(str(val) for val in row.tolist()).upper()
    
    # Detectar las filas de categorías
    category_keywords = ['LINEA ALTO RENDIMIENTO', 'LINEA PREMIUM', 'LINEA IRON', 'LINEA BEAUTY', 'LINEA PRE_WORKOUT', 'LINEA NUTRICION',
                            'LINEA KIDS', 'LINEA VEGGIE PLANT BASED', 'ACCESORIOS']
    is_category_row = any(keyword in row_values_str for keyword in category_keywords)

    if is_category_row:
        category_name = next((val for val in row.tolist() if str(val).strip()), None)
        if category_name:
            cleaned_name = re.sub(r'(LÍNEA|LINEA)\s*', '', str(category_name), flags=re.IGNORECASE).strip()
            if cleaned_name.upper() not in ['DESCRIPCIÓN', 'PRESENTACIÓN', 'CONTENIDO NETO', 'CANTIDAD POR BULTO', 'PRECIO UNITARIO NETO', 'PRECIO UNITARIO CON IVA']:
                current_category = cleaned_name
        continue

   


df.head(20)
